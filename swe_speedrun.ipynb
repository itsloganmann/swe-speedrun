# %% [markdown]
# # Task
# Summarize the successful execution of the experimentation pipeline for gpt nano using the SWE Speedrun scaffold.

# %% [markdown]
# ## Clone Repository
#
# ### Subtask:
# Clone the 'itsloganmann/swe-speedrun' Git repository to access the project files.

# %% [markdown]
# **Reasoning**:
# To clone the Git repository, I will execute the `git clone` command in a code cell.

# %%
git_repo_url = "https://github.com/itsloganmann/swe-speedrun.git"
# !git clone {git_repo_url}
print(f"Successfully cloned the repository: {git_repo_url}")
# Out:
# Cloning into 'swe-speedrun'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 35 (delta 5), reused 26 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 16.85 KiB | 230.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Successfully cloned the repository: https://github.com/itsloganmann/swe-speedrun.git

# %% [markdown]
# ## Install Dependencies
#
# ### Subtask:
# Install the necessary Python dependencies by running 'pip install -r requirements.txt' within the cloned repository's directory. This will set up the environment for the experiment.

# %% [markdown]
# **Reasoning**:
# To install the dependencies, I need to navigate into the cloned repository's directory and then execute the pip install command.

# %%
import os
# %cd swe-speedrun
# !pip install -r requirements.txt
# Out:
# /content/swe-speedrun
# ...

# %% [markdown]
# ## Prepare Dataset
#
# ### Subtask:
# Prepare the dataset by executing 'python scripts/build_speedrun_dataset.py --dataset anchen-li/swe-bench-lite --limit 500 --output data/processed/swe-speedrun.jsonl' and then 'python scripts/summarize_dataset.py data/processed/swe-speedrun.jsonl'. This will build and summarize the speedrun dataset.

# %% [markdown]
# **Reasoning**:
# To prepare the dataset, I need to execute two Python scripts: first, to build the dataset with specified parameters, and then to summarize the newly created dataset. Both commands will be run as shell commands within the current directory.

# %%
import os

# Ensure the output directory exists
os.makedirs('data/processed', exist_ok=True)

# Build the speedrun dataset
# !python scripts/build_speedrun_dataset.py --dataset anchen-li/swe-bench-lite --limit 500 --output data/processed/swe-speedrun.jsonl

# Summarize the dataset
# !python scripts/summarize_dataset.py data/processed/swe-speedrun.jsonl
# Out:
# Traceback (most recent call last):
#   File "/content/swe-speedrun/scripts/build_speedrun_dataset.py", line 9, in <module>
#     from swe_scaffold.config import SpeedrunConfig
# ModuleNotFoundError: No module named 'swe_scaffold'
# Traceback (most recent call last):
#   File "/content/swe-speedrun/scripts/summarize_dataset.py", line 35, in <module>
#     main()
#   File "/content/swe-speedrun/scripts/summarize_dataset.py", line 19, in main
#     with args.dataset.open("r", encoding="utf-8") as handle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 1013, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/swe-speedrun.jsonl'

# %%
pip install -r requirements.txt

# %%
cd scripts/
# Out:
# /content/swe-speedrun/scripts

# %%
# !python build_speedrun_dataset.py
# Out:
# 2025-11-12 20:44:56.206134: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 20:44:56.224470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762980296.246443    3681 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762980296.253099    3681 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip install swe_scaffold
# Out:
# ERROR: Could not find a version that satisfies the requirement swe_scaffold (from versions: none)
# ERROR: No matching distribution found for swe_scaffold

# %%
pip install -e .
# Out:
# Obtaining file:///content/swe-speedrun
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for swe-speedrun-scaffold (pyproject.toml) ... done
#   Created wheel for swe-speedrun-scaffold: filename=swe_speedrun_scaffold-0.1.0-0.editable-py3-none-any.whl size=4016 sha256=7bd52edfdb4c35676af9ba26ee3a4c431c6c5f53bef12901343677b59853e054
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cmhla_mr/wheels/ce/a5/7a/f41f5b40587e6c6d5195762488c818fc2e79445bf48b62872a
# Successfully built swe-speedrun-scaffold
# ...

# %%
# !python scripts/build_speedrun_dataset.py --limit 500 --output data/processed/swe-speedrun.jsonl
# Out:
# 2025-11-12 19:59:58.214283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762977598.227791    5610 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762977598.231686    5610 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762977598.241835    5610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/summarize_dataset.py
# Out:
# usage: summarize_dataset.py [-h] dataset
# summarize_dataset.py: error: the following arguments are required: dataset

# %%
# !python scripts/summarize_dataset.py scripts/data/processed/swe-speedrun.jsonl
# Out:
# Examples: 23
# Label distribution:
#   - failure: 23
# Average prompt characters: 1790.5
# Average response characters: 0.0

# %%
ls
# Out:
# configs/        README.md         swe_scaffold/
# data/           requirements.txt  swe_speedrun_scaffold.egg-info/
# pyproject.toml  scripts/          training/

# %%
# !python training/train_qwen_speedrun.py configs/speedrun.json scripts/data/processed/swe-speedrun.jsonl
# Out:
# 2025-11-12 21:01:30.054420: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 21:01:30.071986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762981290.093681    8093 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762981290.100249    8093 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python training/evaluate_qwen_speedrun.py artifacts/checkpoints/qwen-speedrun scripts/data/processed/swe-speedrun.jsonl
# Out:
# 2025-11-12 21:02:59.445032: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 21:02:59.463230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762981379.484331    8560 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762981379.490731    8560 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git push
# Out:
# Enumerating objects: 21, done.
# Counting objects: 100% (21/21), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (15/15), 17.42 KiB | 5.81 MiB/s, done.
# Total 15 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/itsloganmann/swe-speedrun.git
#    a6e3b86..8e86003  main -> main

# %%
# !git push
# Out:
# Enumerating objects: 35, done.
# Counting objects: 100% (35/35), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (31/31), done.
# Writing objects: 100% (33/33), 42.67 MiB | 10.52 MiB/s, done.
# Total 33 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/itsloganmann/swe-speedrun.git
#    9685ca6..2dbc230  main -> main
